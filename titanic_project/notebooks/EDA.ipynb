# %% [markdown]
# # Titanic EDA (Exploratory Data Analysis)
#
# 타이타닉 데이터셋 탐색

# %%
import pandas as pd
import os

# 프로젝트 루트 (titanic_project)
root = os.path.dirname(os.getcwd()) if os.path.basename(os.getcwd()) == 'notebooks' else os.getcwd()
train = pd.read_csv(os.path.join(root, 'data', 'raw', 'train.csv'))
train.head()

# %%
train.info()
train.describe()
